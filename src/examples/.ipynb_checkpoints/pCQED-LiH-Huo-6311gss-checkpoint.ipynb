# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.5925193790543624
# CQED-RHF One-electron energy      = -12.5918498866481361
# Nuclear repulsion energy          = 1.0583544213400000
# Dipole energy                     = 0.0006804157725302
# SCF Iteration   1: Energy = -7.9840375285780594   dE = -7.98404E+00   dRMS = 7.58437E-06
# SCF Iteration   2: Energy = -7.9840376228143350   dE = -9.42363E-08   dRMS = 2.66874E-06
# SCF Iteration   3: Energy = -7.9840376396926471   dE = -1.68783E-08   dRMS = 7.93097E-07
# SCF Iteration   4: Energy = -7.9840376413537788   dE = -1.66113E-09   dRMS = 1.41283E-07
# SCF Iteration   5: Energy = -7.9840376413837424   dE = -2.99636E-11   dRMS = 2.29939E-08
# SCF Iteration   6: Energy = -7.9840376413847371   dE = -9.94760E-13   dRMS = 1.12146E-09
# SCF Iteration   7: Energy = -7.9840376413847336   dE =  3.55271E-15   dRMS = 9.73520E-11
# Total time for SCF iterations: 0.010 seconds
#
# QED-RHF   energy: -7.98403764 hartree
# Psi4  SCF energy: -7.98420580 hartree
#  Completed QED-RHF in 0.1689472198486328 seconds
#  Completed 1HSO Build in 0.000988006591796875 seconds
#  Completed ERI Build in 0.02639317512512207 seconds
#  Completed 2D build in 0.02326679229736328 seconds
#  Completed 1G build in 7.700920104980469e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008680820465087891 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0019168853759765625 seconds
#  Completed constant offset matrix in 0.0005099773406982422 seconds
#  Completed Hamiltonian build in 0.6931900978088379 seconds
# [-7.9848177366 -7.8640432702 -7.8443027321 -7.8351500625 -7.7967681454 -7.7967681454 -7.790848489  -7.790848489  -7.7563223937 -7.7437841386]

# %%
mol_tmpl = """
Li
H 1 **R**
symmetry c1
"""

mol_str = """
Li
H 1 1.5
symmetry c1
"""

N_R = 50
N_el = 50
all_states = np.linspace(0, N_el-1, N_el, dtype=int)
r_array = np.linspace(1.4, 2.2, N_R)

E_array = np.zeros((N_R, N_el))
Mu_array = np.zeros((N_R, N_el, N_el, 3))
psi4.set_options(options_dict)

r_idx = 0
for r in r_array:
    mol_str = mol_tmpl.replace("**R**", str(r))
    print(mol_str)
    mol = psi4.geometry(mol_str)
    #scf_e, wfn = psi4.energy('SCF', return_wfn=True)
    #fci_energy = psi4.energy('fci',ref_wfn=wfn)
    
    LiH = PFHamiltonianGenerator(mol_str, options_dict, cavity_dict)
    #assert np.isclose(fci_energy, LiH.CIeigs[0], 1e-7)
    # sort out states with dipole-allowed transition from ground state
    #singlet_states = LiH.sort_dipole_allowed_states( N_el)
    #print(singlet_states)
    
    #E_array[r_idx, :] = LiH.CIeigs[singlet_states]
    #Mu_array[r_idx, :, :, :] = LiH.compute_dipole_moments(singlet_states)
    
    # uncomment to try not sorting singlet states
    E_array[r_idx, :] = LiH.CIeigs[all_states]
    Mu_array[r_idx, :, :, :] = LiH.compute_dipole_moments(all_states)
    
    r_idx += 1
# Out:
# Li
# H 1 1.4
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.7385117713869249
# CQED-RHF One-electron energy      = -12.7385117713869249
# Nuclear repulsion energy          = 1.1339511657214287
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9790995550487072   dE = -7.97910E+00   dRMS = 6.56523E-12
# SCF Iteration   2: Energy = -7.9790995550486983   dE =  8.88178E-15   dRMS = 2.04333E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.
-05 seconds
#  Completed the Dipole Matrix Build in 0.0008709430694580078 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001811981201171875 seconds
#  Completed constant offset matrix in 0.000270843505859375 seconds
#  Completed Hamiltonian build in 0.6865253448486328 seconds
#
# Li
# H 1 1.8081632653061224
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.2070423445055649
# CQED-RHF One-electron energy      = -12.2070423445055649
# Nuclear repulsion energy          = 0.8779802479513544
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9818265803298587   dE = -7.98183E+00   dRMS = 1.28369E-12
# SCF Iteration   2: Energy = -7.9818265803298711   dE = -1.24345E-14   dRMS = 5.21596E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98182658 hartree
# Psi4  SCF energy: -7.98182658 hartree
#  Completed QED-RHF in 0.12451696395874023 seconds
#  Completed 1HSO Build in 0.001094818115234375 seconds
#  Completed ERI Build in 0.02705693244934082 seconds
#  Completed 2D build in 0.024592161178588867 seconds
#  Completed 1G build in 6.985664367675781e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008959770202636719 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018410682678222656 seconds
#  Completed constant offset matrix in 0.00026416778564453125 seconds
#  Completed Hamiltonian build in 0.7005157470703125 seconds
#
# Li
# H 1 1.8244897959183675
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.1890065532280847
# CQED-RHF One-electron energy      = -12.1890065532280847
# Nuclear repulsion energy          = 0.8701236014372483
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9812340138205791   dE = -7.98123E+00   dRMS = 1.28934E-12
# SCF Iteration   2: Energy = -7.9812340138206057   dE = -2.66454E-14   dRMS = 5.25150E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98123401 hartree
# Psi4  SCF energy: -7.98123401 hartree
#  Completed QED-RHF in 0.12454581260681152 seconds
#  Completed 1HSO Build in 0.0009999275207519531 seconds
#  Completed ERI Build in 0.02683281898498535 seconds
#  Completed 2D build in 0.025526046752929688 seconds
#  Completed 1G build in 7.009506225585938e-05 seconds
#  Completed the Dipole Matrix Build in 0.0009207725524902344 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018320083618164062 seconds
#  Completed constant offset matrix in 0.00032782554626464844 seconds
#  Completed Hamiltonian build in 0.6932332515716553 seconds
#
# Li
# H 1 1.8408163265306123
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.1711869483450101
# CQED-RHF One-electron energy      = -12.1711869483450101
# Nuclear repulsion energy          = 0.8624063189411308
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9806111882634756   dE = -7.98061E+00   dRMS = 1.29470E-12
# SCF Iteration   2: Energy = -7.9806111882634774   dE = -1.77636E-15   dRMS = 5.28558E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98061119 hartree
# Psi4  SCF energy: -7.98061119 hartree
#  Completed QED-RHF in 0.12390518188476562 seconds
#  Completed 1HSO Build in 0.0010080337524414062 seconds
#  Completed ERI Build in 0.026441097259521484 seconds
#  Completed 2D build in 0.023272037506103516 seconds
#  Completed 1G build in 7.605552673339844e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008788108825683594 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018661022186279297 seconds
#  Completed constant offset matrix in 0.00027489662170410156 seconds
#  Completed Hamiltonian build in 0.7000079154968262 seconds
#
# Li
# H 1 1.8571428571428572
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.1535803784203331
# CQED-RHF One-electron energy      = -12.1535803784203331
# Nuclear repulsion energy          = 0.8548247249284615
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9799598827472433   dE = -7.97996E+00   dRMS = 1.30031E-12
# SCF Iteration   2: Energy = -7.9799598827472664   dE = -2.30926E-14   dRMS = 5.31991E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97995988 hartree
# Psi4  SCF energy: -7.97995988 hartree
#  Completed QED-RHF in 0.12882494926452637 seconds
#  Completed 1HSO Build in 0.0009019374847412109 seconds
#  Completed ERI Build in 0.026507139205932617 seconds
#  Completed 2D build in 0.02338695526123047 seconds
#  Completed 1G build in 7.176399230957031e-05 seconds
#  Completed the Dipole Matrix Build in 0.000881195068359375 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0
e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008602142333984375 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018258094787597656 seconds
#  Completed constant offset matrix in 0.00030112266540527344 seconds
#  Completed Hamiltonian build in 0.707099199295044 seconds
#
# Li
# H 1 1.9387755102040818
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.0686363169914408
# CQED-RHF One-electron energy      = -12.0686363169914408
# Nuclear repulsion energy          = 0.8188321049314738
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9763325420787190   dE = -7.97633E+00   dRMS = 1.35576E-12
# SCF Iteration   2: Energy = -7.9763325420787279   dE = -8.88178E-15   dRMS = 5.59163E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97633254 hartree
# Psi4  SCF energy: -7.97633254 hartree
#  Completed QED-RHF in 0.12367105484008789 seconds
#  Completed 1HSO Build in 0.0009448528289794922 seconds
#  Completed ERI Build in 0.026567935943603516 seconds
#  Completed 2D build in 0.023356199264526367 seconds
#  Completed 1G build in 7.677078247070312e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008602142333984375 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018341541290283203 seconds
#  Completed constant offset matrix in 0.0002238750457763672 seconds
#  Completed Hamiltonian build in 0.7044970989227295 seconds
#
# Li
# H 1 1.9551020408163267
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.0522446077941368
# CQED-RHF One-electron energy      = -12.0522446077941368
# Nuclear repulsion energy          = 0.8119942585437370
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9755431170565627   dE = -7.97554E+00   dRMS = 1.37730E-12
# SCF Iteration   2: Energy = -7.9755431170565556   dE =  7.10543E-15   dRMS = 5.68542E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97554312 hartree
# Psi4  SCF energy: -7.97554312 hartree
#  Completed QED-RHF in 0.12666606903076172 seconds
#  Completed 1HSO Build in 0.0010738372802734375 seconds
#  Completed ERI Build in 0.026639223098754883 seconds
#  Completed 2D build in 0.023228883743286133 seconds
#  Completed 1G build in 6.985664367675781e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008881092071533203 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018551349639892578 seconds
#  Completed constant offset matrix in 0.00021767616271972656 seconds
#  Completed Hamiltonian build in 0.7108252048492432 seconds
#
# Li
# H 1 1.9714285714285715
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.0360452726277689
# CQED-RHF One-electron energy      = -12.0360452726277689
# Nuclear repulsion energy          = 0.8052696684108697
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9747354497270768   dE = -7.97474E+00   dRMS = 1.40372E-12
# SCF Iteration   2: Energy = -7.9747354497270857   dE = -8.88178E-15   dRMS = 5.79739E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97473545 hartree
# Psi4  SCF energy: -7.97473545 hartree
#  Completed QED-RHF in 0.12375783920288086 seconds
#  Completed 1HSO Build in 0.0009000301361083984 seconds
#  Completed ERI Build in 0.026495933532714844 seconds
#  Completed 2D build in 0.024177074432373047 seconds
#  Completed 1G build in 8.296966552734375e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008568763732910156 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018076896667480469 seconds
#  Completed constant offset matrix in 0.0002162456512451172 seconds
#  Completed Hamiltonian build in 0.7087559700012207 seconds
#
# Li
# H 1 1.9877551020408164
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.0200355507026160
# CQED-RHF One-electron energy      = -12.0200355507026160
# Nuclear repulsion energy          = 0.7986555438243326
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9739107317498563   dE = -7.97391E+00   dRMS = 1.43512E-12
# SCF Iteration   2: Energy = -7.9739107317498545   dE =  1.77636E-15   dRMS = 5.93067E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97391073 hartree
# Psi4  SCF energy: -7.97391073 hartree
#  Completed QED-RHF in 0.12389898300170898 seconds
#  Completed 1HSO Build in 0.0011060237884521484 seconds
#  Completed ERI Build in 0.02663898468017578 seconds
#  Completed 2D build in 0.024191856384277344 seconds
#  Completed 1G build in 8.0108642578125e-05 seconds
#  Completed the Dipole Matrix Build in 0.0
seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018451213836669922 seconds
#  Completed constant offset matrix in 0.00023221969604492188 seconds
#  Completed Hamiltonian build in 0.6920788288116455 seconds
#
# Li
# H 1 2.069387755102041
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9427376675550381
# CQED-RHF One-electron energy      = -11.9427376675550381
# Nuclear repulsion energy          = 0.7671503941665679
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9695692041497379   dE = -7.96957E+00   dRMS = 1.66922E-12
# SCF Iteration   2: Energy = -7.9695692041497468   dE = -8.88178E-15   dRMS = 6.90515E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96956920 hartree
# Psi4  SCF energy: -7.96956920 hartree
#  Completed QED-RHF in 0.12344217300415039 seconds
#  Completed 1HSO Build in 0.0009407997131347656 seconds
#  Completed ERI Build in 0.026551008224487305 seconds
#  Completed 2D build in 0.023162126541137695 seconds
#  Completed 1G build in 6.985664367675781e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008671283721923828 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001806020736694336 seconds
#  Completed constant offset matrix in 0.00029397010803222656 seconds
#  Completed Hamiltonian build in 0.6987209320068359 seconds
#
# Li
# H 1 2.085714285714286
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9278101568466788
# CQED-RHF One-electron energy      = -11.9278101568466788
# Nuclear repulsion energy          = 0.7611453030184931
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9686641658544470   dE = -7.96866E+00   dRMS = 1.73003E-12
# SCF Iteration   2: Energy = -7.9686641658544293   dE =  1.77636E-14   dRMS = 7.15837E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96866417 hartree
# Psi4  SCF energy: -7.96866417 hartree
#  Completed QED-RHF in 0.12407302856445312 seconds
#  Completed 1HSO Build in 0.001065969467163086 seconds
#  Completed ERI Build in 0.02672410011291504 seconds
#  Completed 2D build in 0.023459196090698242 seconds
#  Completed 1G build in 7.677078247070312e-05 seconds
#  Completed the Dipole Matrix Build in 0.00090789794921875 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018355846405029297 seconds
#  Completed constant offset matrix in 0.0002570152282714844 seconds
#  Completed Hamiltonian build in 0.7121152877807617 seconds
#
# Li
# H 1 2.1020408163265305
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9130541747459819
# CQED-RHF One-electron energy      = -11.9130541747459819
# Nuclear repulsion energy          = 0.7552334948397089
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9677489522230704   dE = -7.96775E+00   dRMS = 1.79495E-12
# SCF Iteration   2: Energy = -7.9677489522230598   dE =  1.06581E-14   dRMS = 7.42890E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96774895 hartree
# Psi4  SCF energy: -7.96774895 hartree
#  Completed QED-RHF in 0.12677311897277832 seconds
#  Completed 1HSO Build in 0.0010609626770019531 seconds
#  Completed ERI Build in 0.02817702293395996 seconds
#  Completed 2D build in 0.023746013641357422 seconds
#  Completed 1G build in 8.797645568847656e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008800029754638672 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018100738525390625 seconds
#  Completed constant offset matrix in 0.0002560615539550781 seconds
#  Completed Hamiltonian build in 0.6970980167388916 seconds
#
# Li
# H 1 2.1183673469387756
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8984673074615532
# CQED-RHF One-electron energy      = -11.8984673074615532
# Nuclear repulsion energy          = 0.7494128127985549
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9668243653900443   dE = -7.96682E+00   dRMS = 1.86332E-12
# SCF Iteration   2: Energy = -7.9668243653900301   dE =  1.42109E-14   dRMS = 7.71349E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96682437 hartree
# Psi4  SCF energy: -7.96682437 hartree
#  Completed QED-RHF in 0.12402606010437012 seconds
#  Completed 1HSO Build in 0.0010118484497070312 seconds
#  Completed ERI Build in 0.02650308609008789 seconds
#  Completed 2D build in 0.023990869522094727 seconds
#  Completed 1G build in 6.818771362304688e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008778572082519531 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001847982406616211 seconds
#  Completed constant offset matrix in 0.00026297569274902344 seconds
#  Completed Hamiltonian build in 0.6858508586883545 seconds
#
# Li
# H 1 2.1346938775510207
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8840471817534095
# CQED-RHF One-electron energy      = -11.8840471817534095
# Nuclear repulsion energy          = 0.7436811660467495
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9658911688718588   dE = -7.96589E+00   dRMS = 1.93523E-12
# SCF Iteration   2: Energy = -7.9658911688718446   dE =  1.42109E-14   dRMS = 8.01350E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96589117 hartree
# Psi4  SCF energy: -7.96589117 hartree
#  Completed QED-RHF in 0.12432312965393066 seconds
#  Completed 1HSO Build in 0.0009551048278808594 seconds
#  Completed ERI Build in 0.02684497833251953 seconds
#  Completed 2D build in 0.023138999938964844 seconds
#  Completed 1G build in 6.890296936035156e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008590221405029297 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018260478973388672 seconds
#  Completed constant offset matrix in 0.0002338886260986328 seconds
#  Completed Hamiltonian build in 0.6975522041320801 seconds
#
# Li
# H 1 2.1510204081632653
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8697914642944582
# CQED-RHF One-electron energy      = -11.8697914642944582
# Nuclear repulsion energy          = 0.7380365272152751
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9649500894169130   dE = -7.96495E+00   dRMS = 2.00995E-12
# SCF Iteration   2: Energy = -7.9649500894169130   dE =  0.00000E+00   dRMS = 8.32443E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96495009 hartree
# Psi4  SCF energy: -7.96495009 hartree
#  Completed QED-RHF in 0.12363910675048828 seconds
#  Completed 1HSO Build in 0.0010361671447753906 seconds
#  Completed ERI Build in 0.027248859405517578 seconds
#  Completed 2D build in 0.02687692642211914 seconds
#  Completed 1G build in 7.319450378417969e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008950233459472656 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018410682678222656 seconds
#  Completed constant offset matrix in 0.00035309791564941406 seconds
#  Completed Hamiltonian build in 0.6978669166564941 seconds
#
# Li
# H 1 2.1673469387755104
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8556978610235859
# CQED-RHF One-electron energy      = -11.8556978610235859
# Nuclear repulsion energy          = 0.7324769300234460
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9640018187558335   dE = -7.96400E+00   dRMS = 2.08715E-12
# SCF Iteration   2: Energy = -7.9640018187558317   dE =  1.77636E-15   dRMS = 8.64589E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96400182 hartree
# Psi4  SCF energy: -7.96400182 hartree
#  Completed QED-RHF in 0.12321591377258301 seconds
#  Completed 1HSO Build in 0.001096963882446289 seconds
#  Completed ERI Build in 0.02686309814453125 seconds
#  Completed 2D build in 0.023694276809692383 seconds
#  Completed 1G build in 6.580352783203125e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008859634399414062 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018317699432373047 seconds
#  Completed constant offset matrix in 0.0002551078796386719 seconds
#  Completed Hamiltonian build in 0.7087070941925049 seconds
#
# Li
# H 1 2.183673469387755
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8417641164898626
# CQED-RHF One-electron energy      = -11.8417641164898626
# Nuclear repulsion energy          = 0.7270004669952337
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9630470152586401   dE = -7.96305E+00   dRMS = 2.16656E-12
# SCF Iteration   2: Energy = -7.9630470152586579   dE = -1.77636E-14   dRMS = 8.97695E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96304702 hartree
# Psi4  SCF energy: -7.96304702 hartree
#  Completed QED-RHF in 0.12339520454406738 seconds
#  Completed 1HSO Build in 0.0009391307830810547 seconds
#  Completed ERI Build in 0.026391983032226562 seconds
#  Completed 2D build in 0.02315497398376465 seconds
#  Completed 1G build in 6.890296936035156e-05 seconds
#  Completed the Dipole Matrix Build in 0.0009331703186035156 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018198490142822266 seconds
#  Completed constant offset matrix in 0.0002543926239013672 seconds
#  Completed Hamiltonian build in 0.6962597370147705 seconds
#
# Li
# H 1 2.2
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8279880131879054
# CQED-RHF One-electron energy      = -11.8279880131879054
# Nuclear repulsion energy          = 0.7216052872772727
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9620863055039024   dE = -7.96209E+00   dRMS = 2.24769E-12
# SCF Iteration   2: Energy = -7.9620863055039113   dE = -8.88178E-15   dRMS = 9.31498E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96208631 hartree
# Psi4  SCF energy: -7.96208631 hartree
#  Completed QED-RHF in 0.12398886680603027 seconds
#  Completed 1HSO Build in 0.0009031295776367188 seconds
#  Completed ERI Build in 0.026684999465942383 seconds
#  Completed 2D build in 0.02360701560974121 seconds
#  Completed 1G build in 7.605552673339844e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008809566497802734 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018620491027832031 seconds
#  Completed constant offset matrix in 0.0003001689910888672 seconds
#  Completed Hamiltonian build in 0.7105069160461426 seconds

# %%
from matplotlib import pyplot as plt

# %%
print(r_array)
print(E_array[:,1]-E_array[:,0])

plt.plot(r_array, E_array[:,0]+0.1208, label="E0")
plt.plot(r_array, E_array[:,1], label="E1")
plt.plot(r_array, E_array[:,2], label="E2")
plt.plot(r_array, E_array[:,3], label="E3")
plt.legend()
#plt.xlim(1.79, 1.81)
plt.show()

# %% [markdown]
# \begin{equation}
# \hat{H}_{\alpha n, \beta m} = \left( E_{\alpha}(R) + n \omega \right) \delta_{\alpha \beta} \delta_{nm} + \sqrt{\frac{\omega}{2}} \lambda \cdot \mu_{\alpha \beta}(R) \left(\sqrt{n} \delta_{n,m-1} + \sqrt{n+1} \delta_{n,m+1} \right)  \\
# +\frac{1}{2} \sum_{\gamma = 1}^N \lambda \cdot \mu_{\alpha, \gamma}(R) \lambda \cdot \mu_{\gamma, \beta} \delta_{nm}
# \end{equation}

# %%
def build_pf_hamiltonian(n_el, n_ph, E_R, omega, lamvec, mu):
    """
    Given an array of n_el E_R values and an n_ph states with fundamental energy omega
    build the PF Hamiltonian
    
    n_el : int
        the number of electronic states (n_el = 1 means only ground-state)
    
    n_ph : int
        the number of photon occupation states (n_ph = 1 means only the |0> state)
    
    E_R : np.array of floats
        the electronic energies
        
    omega : float
        the energy of the photonic mode
        
    lamvec : np.array of floats
        the lambda vector
        
    mu : (n_el x n_el x 3) np.array of floats 
        mu[i, j, k] is the kth cartesian component of the dipole moment expectation value between 
        state i and state j
    
    """
    H_PF = np.zeros((n_el * n_ph, n_el * n_ph))
    
    # take care of the diagonals first
    # bare electronic and photonic energy
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            H_PF[na,na] = E_R[a] + n * omega
        
    # diagonal dipole self energy
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            for g in range(n_el):
                H_PF[na,na] += 0.5 * np.dot(lamvec, mu[a,g,:]) * np.dot(lamvec, mu[g,a,:])
            
    # off-diagonal dipole self energy
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            for b in range(n_el):
                nb = n * n_el + b
                for g in range(n_el):
                    if a != b:
                        H_PF[na, nb] += 0.5 * np.dot(lamvec, mu[a,g,:]) * np.dot(lamvec, mu[g, b, :])
                
    # off-diagonal bilinear coupling
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            
            for m in range(n_ph):
                for b in range(n_el):
                    mb = m * n_el + b
                    
                    if n == (m-1) and a != b:
                        #print(n, a, na, m, b, mb)
                        H_PF[na,mb] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m) 
                        H_PF[mb, na] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m) 
                        
                    elif n == (m+1) and a != b:
                        #print(n, a, na, m, b, mb)
                        H_PF[na, mb] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m+1) 
                        H_PF[mb, na] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m+1)
                        
    
    return H_PF

# %% [markdown]
# \begin{equation}
# \hat{H}_{\alpha n, \beta m} = \left( E_{\alpha}(R) + n \omega \right) \delta_{\alpha \beta} \delta_{nm} + \sqrt{\frac{\omega}{2}} \lambda \cdot \mu_{\alpha \beta}(R) \left(\sqrt{n} \delta_{n,m-1} + \sqrt{n+1} \delta_{n,m+1} \right)  \\
# +\frac{1}{2} \sum_{\gamma = 1}^N \lambda \cdot \mu_{\alpha, \gamma}(R) \lambda \cdot \mu_{\gamma, \beta} \delta_{nm}
# \end{equation}

# %%
np.set_printoptions(precision=6, linewidth=200, suppress=True)
omega_cav = 0.12086
lambda_vector = np.array([0., 0., 0.08])
N_el = 3
N_ph = 2

_HPF = build_pf_hamiltonian(N_el, N_ph, E_array[0,:], omega_cav, lambda_vector, Mu_array[0, :, :, :])
print("H")
print(_HPF)

# %% [markdown]
# We want to investigate the mean absolute error of a given polariton potential energy surface as a
# function of electronic and photonic truncation:
#
# $$ {\rm MAE} = \frac{1}{N_R} \sum_i^{N_R} \left| E(R_i) - E^{'}(R_i) \right| $$
#
# where $E^{'}(R_i)$ is a value of the polaritonic PES for a truncated level of theory and $E(R_i)$ is the exact value.

# %%
def MAE(E, Ep):
    """
    function to return the mean absolute error of the approximate PES stored in Ep relative to 
    the exact PES stored in E
    """
    # get length
    _NR = len(E)
    
    # take element-by-element difference
    _diff = E - Ep
    
    # compute absolute value of differences
    _absdiff = np.abs(_diff)
    
    # return sum divided by _NR
    return np.sum(_absdiff) / _NR

# %%
N_el = 50
N_ph = 2

#PF_EIG = np.zeros((N_R, N_el * N_ph))
#PF_5050 = np.zeros((N_R, N_el * N_ph))
MAE_array = np.zeros((20,20,3))
N_el_array = np.linspace(2, 21, 20, dtype=int)
N_ph_array = np.linspace(2, 21, 20, dtype=int)
print(N_el_array)
print(N_ph_array)

# %%
N_el = 10
N_ph = 10
pf_array = np.zeros((N_R, N_el * N_ph ))
for k in range(N_R):           
    _HPF = build_pf_hamiltonian(N_el, N_ph, E_array[k,:], omega_cav, lambda_vector, Mu_array[k, :, :, :])
    pf_e, pf_c = np.linalg.eigh(_HPF)
    pf_array[k,:] = pf_e



#print(r_array[i], pf_e[0], pf_e[1],  pf_e[2], pf_e[2])
#mae_g = MAE(pf_tmp[:,0], PF_5050[:,0])
#mae_lp = MAE(pf_tmp[:,1], PF_5050[:,1])
#mae_up = MAE(pf_tmp[:,2], PF_5050[:,2])
#MAE_array[i, j, 0] = mae_g
#MAE_array[i, j, 1] = mae_lp
#MAE_array[i, j, 2] = mae_up
#print(F'Nel : {N_el}, Nph : {N_ph}, mae_g : {mae_g}, mae_lp : {mae_lp}, mae_up : {mae_up}')

# %%
#plt.plot(r_array, Eg_QED_FCI_Np_1)
plt.plot(r_array, pf_array[:,0])
plt.plot(r_array, pf_array[:,1])
#plt.plot(r_array, E3_QED_FCI_Np_1, label="QED-FCI")
#plt.plot(r_array, E3_QED_FCI_Np_5, label="QED-FCI")
plt.plot(r_array, pf_array[:,2])
plt.plot(r_array, pf_array[:,3])
#plt.plot(r_array, pf_array[:,4])
plt.legend()

# %%
for i in range(N_R):
    print(F'{r_array[i]}, {pf_array[i,0]}, {pf_array[i,1]}, {pf_array[i,2]}, {pf_array[i,3]}, {pf_array[i,3]} ')

# %%
# we will compare to this!
#PF_2020 = np.copy(PF_EIG)
#PF_22 = np.copy(PF_EIG)

print(MAE(PF_5020[:,0], PF_2020[:,0]))
print(MAE(PF_5020[:,1], PF_2020[:,1]))
print(MAE(PF_5020[:,2], PF_2020[:,2]))

print(MAE(PF_5050[:,0], PF_2020[:,0]))
print(MAE(PF_5050[:,1], PF_2020[:,1]))
print(MAE(PF_5050[:,2], PF_2020[:,2]))

print(MAE(PF_5050[:,0], PF_5020[:,0]))
print(MAE(PF_5050[:,1], PF_5020[:,1]))
print(MAE(PF_5050[:,2], PF_5020[:,2]))
#omega_cav = 0.120000
#lambda_vector = np.array([0, 0.0, 0.05])
#numpy.savetxt(fname, X, fmt='%.18e', delimiter=' ', newline='\n', header='', footer='', comments='# ', encoding=None)[source]
np.savetxt('PF_5050_om_zp12_lamz_zp05.out', PF_5050, fmt='%16.12e', delimiter=',', newline='\n', header="N_el = 50, N_ph = 50, omega = 0.12, lambda = 0., 0., 0.05, r_array = np.linspace(1.4, 2.2, N_R)" )

# %%
for i in range(20):

    for j in range(20):
        N_el = N_el_array[i]
        N_ph = N_ph_array[j]
        print(F'{N_el}, {N_ph}, {MAE_array[i, j, 0]}, {MAE_array[i, j, 1]}, {MAE_array[i, j, 2]}')
        
    print('')

# %%
#plt.plot(r_array, PF_2020[:,0], 'black', label="LP - 20-20")
#plt.plot(r_array, PF_WTRIP[:,0], 'ro', label="LP - 2-2")
plt.plot(r_array, PF_2020[:,1], 'r--', label="LP - 20-2")
plt.plot(r_array, PF_WTRIP[:,2], 'purple', label="UP - 20-20")
plt.plot(r_array, PF_2020[:,2], 'b--', label="UP - 20-2")
plt.plot(r_array, PF_WTRIP[:,3], 'bo', label="UP - 2-2")
plt.legend()
plt.show()


plt.plot(r_array,PF_2020[:,2]- PF_WTRIP[:,3])
#plt.xlim(1.62, 2.2)
plt.show()

print(PF_2020[:,2]- PF_WTRIP[:,3])

# %%
plt.plot(r_array, PF_2020[:,1], 'black', label="LP - 20-20")
plt.plot(r_array, PF_22[:,1], 'ro', label="LP - 2-2")
plt.plot(r_array, PF_202[:,1], 'r--', label="LP - 20-2")
plt.plot(r_array, PF_2020[:,2], 'purple', label="UP - 20-20")
plt.plot(r_array, PF_202[:,2], 'b--', label="UP - 20-2")
plt.plot(r_array, PF_22[:,2], 'bo', label="UP - 2-2")
plt.legend()
plt.show()

#plt.plot(r_array, PF_EIG[:,2], 'b--')
#plt.plot(r_array, E_array[:,0]+omega_cav)
#plt.plot(r_array, E_array[:,2])
#plt.plot(r_array, E_array[:,3])
#plt.plot(r_array, PF_EIG[:,3])
#plt.plot(r_array, PF_EIG[:,4])
#plt.plot(r_array, PF_EIG[:,5])

# %%
mol_str = """
Li
H 1 1.8
symmetry c1
"""

options_dict = {
    "basis": "sto-3g",
    "scf_type": "pk",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
    "save_jk" : True
}

cavity_dict = {
    'omega_value' : 0.0,
    'lambda_vector' : np.array([0, 0, 0]),
    'ci_level' : 'fci',
    'full_diagonalization' : True,
    'number_of_photons' : 0
}



E_r_1p8_array = np.zeros(N_el)
Mu_r_1p8_array = np.zeros((N_el, N_el, 3))



mol = psi4.geometry(mol_str)
scf_e, wfn = psi4.energy('SCF', return_wfn=True)
fci_energy = psi4.energy('fci',ref_wfn=wfn)

LiH = PFHamiltonianGenerator(mol_str, options_dict, cavity_dict)
assert np.isclose(fci_energy, LiH.CIeigs[0], 1e-7)
# sort out states with dipole-allowed transition from ground state
singlet_states = LiH.sort_dipole_allowed_states( N_el)
E_r_1p8_array[:] = LiH.CIeigs[singlet_states]
Mu_r_1p8_array = LiH.compute_dipole_moments(singlet_states)

# %%
lam_z = np.linspace(0, 0.1, 50)
pol_v_l = np.zeros((50,3))
print(lam_z)

# %%
N_el = 20
N_ph = 20
for i in range(50):
    lambda_vector[2] = lam_z[i]           
    _HPF = build_pf_hamiltonian(N_el, N_ph, E_array[k,:], omega_cav, lambda_vector, Mu_array[k, :, :, :])
    pf_e, pf_c = np.linalg.eigh(_HPF)
    pol_v_l[i,:] = pf_e[:3]
    print(lam_z[i], pf_e[0], pf_e[1], pf_e[2])

# %%
plt.plot(lam_z, pol_v_l[:,0], label='g')
plt.plot(lam_z, pol_v_l[:,1], label='LP')
plt.plot(lam_z, pol_v_l[:,2], label='UP')

plt.legend()
plt.show()
