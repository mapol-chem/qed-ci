{
    'omega_value' : 0.0,
    'lambda_vector' : np.array([0, 0, 0]),
    'ci_level' : 'cas',
    'full_diagonalization' : True,
    'number_of_photons' : 0, 
    'nact_els' : 4,
    'nact_orbs' : 6
}

mol = psi4.geometry(mol_str)

psi4.set_options(options_dict)

test_pf = PFHamiltonianGenerator(
    mol_str,
    options_dict,
    cavity_dict
)
# Out:
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.5925193790543624
# CQED-RHF One-electron energy      = -12.5925193790543624
# Nuclear repulsion energy          = 1.0583544213400000
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9842058040545920   dE = -7.98421E+00   dRMS = 7.52159E-12
# SCF Iteration   2: Energy = -7.9842058040545743   dE =  1.77636E-14   dRMS = 2.33725E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98420580 hartree
# Psi4  SCF energy: -7.98420580 hartree
#  Completed QED-RHF in 0.3226330280303955 seconds
#  Completed 1HSO Build in 0.0006761550903320312 seconds
#  Completed ERI Build in 0.0283660888671875 seconds
#  Completed 2D build in 0.02782583236694336 seconds
#  Completed 1G build in 7.605552673339844e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008728504180908203 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018270015716552734 seconds
#  Completed constant offset matrix in 0.00014090538024902344 seconds
#  Completed Hamiltonian build in 0.35248613357543945 seconds

# %%
mol_tmpl = """
Li
H 1 **R**
symmetry c1
"""

mol_str = """
Li
H 1 1.5
symmetry c1
"""

N_R = 50
N_el = 50
all_states = np.linspace(0, N_el-1, N_el, dtype=int)
r_array = np.linspace(1.4, 2.2, N_R)

E_array = np.zeros((N_R, N_el))
Mu_array = np.zeros((N_R, N_el, N_el, 3))
psi4.set_options(options_dict)

r_idx = 0
for r in r_array:
    mol_str = mol_tmpl.replace("**R**", str(r))
    print(mol_str)
    mol = psi4.geometry(mol_str)
    #scf_e, wfn = psi4.energy('SCF', return_wfn=True)
    #fci_energy = psi4.energy('fci',ref_wfn=wfn)
    
    LiH = PFHamiltonianGenerator(mol_str, options_dict, cavity_dict)
    #assert np.isclose(fci_energy, LiH.CIeigs[0], 1e-7)
    # sort out states with dipole-allowed transition from ground state
    #singlet_states = LiH.sort_dipole_allowed_states( N_el)
    #print(singlet_states)
    
    #E_array[r_idx, :] = LiH.CIeigs[singlet_states]
    #Mu_array[r_idx, :, :, :] = LiH.compute_dipole_moments(singlet_states)
    
    # uncomment to try not sorting singlet states
    E_array[r_idx, :] = LiH.CIeigs[all_states]
    Mu_array[r_idx, :, :, :] = LiH.compute_dipole_moments(all_states)
    
    r_idx += 1
# Out:
# Li
# H 1 1.4
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.7385117713869249
# CQED-RHF One-electron energy      = -12.7385117713869249
# Nuclear repulsion energy          = 1.1339511657214287
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9790995550487072   dE = -7.97910E+00   dRMS = 6.56523E-12
# SCF Iteration   2: Energy = -7.9790995550486983   dE =  8.88178E-15   dRMS = 2.04333E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97909956 hartree
# Psi4  SCF energy: -7.97909956 hartree
#  Completed QED-RHF in 0.16079282760620117 seconds
#  Completed 1HSO Build in 0.0006070137023925781 seconds
#  Completed ERI Build in 0.02712869644165039 seconds
#  Completed 2D build in 0.025190114974975586 seconds
#  Completed 1G build in 7.605552673339844e-05 seconds
#  Completed the Dipole Matrix Build in 0.000888824462890625 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017559528350830078 seconds
#  Completed constant offset matrix in 0.00016808509826660156 seconds
#  Completed Hamiltonian build in 0.3552539348602295 seconds
#
# Li
# H 1 1.4163265306122448
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12
e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008828639984130859 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017237663269042969 seconds
#  Completed constant offset matrix in 0.00016927719116210938 seconds
#  Completed Hamiltonian build in 0.35111308097839355 seconds
#
# Li
# H 1 1.6122448979591837
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.4415552689976767
# CQED-RHF One-electron energy      = -12.4415552689976767
# Nuclear repulsion energy          = 0.9846715185884811
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9857872929532814   dE = -7.98579E+00   dRMS = 8.25417E-12
# SCF Iteration   2: Energy = -7.9857872929532689   dE =  1.24345E-14   dRMS = 2.57576E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98578729 hartree
# Psi4  SCF energy: -7.98578729 hartree
#  Completed QED-RHF in 0.12145519256591797 seconds
#  Completed 1HSO Build in 0.0006172657012939453 seconds
#  Completed ERI Build in 0.02650284767150879 seconds
#  Completed 2D build in 0.023277997970581055 seconds
#  Completed 1G build in 6.413459777832031e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008678436279296875 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017137527465820312 seconds
#  Completed constant offset matrix in 0.0001952648162841797 seconds
#  Completed Hamiltonian build in 0.35193705558776855 seconds
#
# Li
# H 1 1.6285714285714286
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.4206596430447505
# CQED-RHF One-electron energy      = -12.4206596430447505
# Nuclear repulsion energy          = 0.9748001249184212
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9857357493787040   dE = -7.98574E+00   dRMS = 8.35804E-12
# SCF Iteration   2: Energy = -7.9857357493786969   dE =  7.10543E-15   dRMS = 2.61108E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98573575 hartree
# Psi4  SCF energy: -7.98573575 hartree
#  Completed QED-RHF in 0.12020015716552734 seconds
#  Completed 1HSO Build in 0.0007729530334472656 seconds
#  Completed ERI Build in 0.027714967727661133 seconds
#  Completed 2D build in 0.02319502830505371 seconds
#  Completed 1G build in 7.319450378417969e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008656978607177734 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017271041870117188 seconds
#  Completed constant offset matrix in 0.000164031982421875 seconds
#  Completed Hamiltonian build in 0.3506639003753662 seconds
#
# Li
# H 1 1.6448979591836734
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.4000222937644473
# CQED-RHF One-electron energy      = -12.4000222937644473
# Nuclear repulsion energy          = 0.9651246894353599
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9856237640321162   dE = -7.98562E+00   dRMS = 8.46090E-12
# SCF Iteration   2: Energy = -7.9856237640321446   dE = -2.84217E-14   dRMS = 2.64635E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.98562376 hartree
# Psi4  SCF energy: -7.98562376 hartree
#  Completed QED-RHF in 0.12016820907592773 seconds
#  Completed 1HSO Build in 0.0007359981536865234 seconds
#  Completed ERI Build in 0.027743101119995117 seconds
#  Completed 2D build in 0.023422956466674805 seconds
#  Completed 1G build in 8.082389831542969e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008862018585205078 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017309188842773438 seconds
#  Completed constant offset matrix in 0.00017309188842773438 seconds
#  Completed Hamiltonian build in 0.3517920970916748 seconds
#
# Li
# H 1 1.6612244897959183
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.3796394064506696
# CQED-RHF One-electron energy      = -12.3796394064506696
# Nuclear repulsion energy          = 0.9556394345023342
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9854546199242229   dE = -7.98545E+00   dRMS = 8.56222E-12
# SCF Iteration   2: Energy = -7.9854546199242247   dE = -1.77636E-15   dRMS = 2.68143E-12
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.
seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017998218536376953 seconds
#  Completed constant offset matrix in 0.00017404556274414062 seconds
#  Completed Hamiltonian build in 0.35616207122802734 seconds
#
# Li
# H 1 1.9877551020408164
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.0200355507026160
# CQED-RHF One-electron energy      = -12.0200355507026160
# Nuclear repulsion energy          = 0.7986555438243326
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9739107317498563   dE = -7.97391E+00   dRMS = 1.43512E-12
# SCF Iteration   2: Energy = -7.9739107317498545   dE =  1.77636E-15   dRMS = 5.93067E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97391073 hartree
# Psi4  SCF energy: -7.97391073 hartree
#  Completed QED-RHF in 0.12394118309020996 seconds
#  Completed 1HSO Build in 0.0008111000061035156 seconds
#  Completed ERI Build in 0.027286767959594727 seconds
#  Completed 2D build in 0.023903369903564453 seconds
#  Completed 1G build in 6.67572021484375e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008602142333984375 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017199516296386719 seconds
#  Completed constant offset matrix in 0.00017213821411132812 seconds
#  Completed Hamiltonian build in 0.35153794288635254 seconds
#
# Li
# H 1 2.0040816326530613
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -12.0042127268231624
# CQED-RHF One-electron energy      = -12.0042127268231624
# Nuclear repulsion energy          = 0.7921491850151733
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9730700970245749   dE = -7.97307E+00   dRMS = 1.47180E-12
# SCF Iteration   2: Energy = -7.9730700970245838   dE = -8.88178E-15   dRMS = 6.08372E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97307010 hartree
# Psi4  SCF energy: -7.97307010 hartree
#  Completed QED-RHF in 0.12493586540222168 seconds
#  Completed 1HSO Build in 0.0008280277252197266 seconds
#  Completed ERI Build in 0.027584075927734375 seconds
#  Completed 2D build in 0.023283958435058594 seconds
#  Completed 1G build in 6.389617919921875e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008661746978759766 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001730203628540039 seconds
#  Completed constant offset matrix in 0.0001609325408935547 seconds
#  Completed Hamiltonian build in 0.3546257019042969 seconds
#
# Li
# H 1 2.0204081632653064
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9885741307378968
# CQED-RHF One-electron energy      = -11.9885741307378968
# Nuclear repulsion energy          = 0.7857479794796969
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9722146245730263   dE = -7.97221E+00   dRMS = 1.51369E-12
# SCF Iteration   2: Energy = -7.9722146245730245   dE =  1.77636E-15   dRMS = 6.25794E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97221462 hartree
# Psi4  SCF energy: -7.97221462 hartree
#  Completed QED-RHF in 0.12436676025390625 seconds
#  Completed 1HSO Build in 0.0007238388061523438 seconds
#  Completed ERI Build in 0.02809286117553711 seconds
#  Completed 2D build in 0.023853063583374023 seconds
#  Completed 1G build in 8.0108642578125e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008909702301025391 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017249584197998047 seconds
#  Completed constant offset matrix in 0.00017309188842773438 seconds
#  Completed Hamiltonian build in 0.352031946182251 seconds
#
# Li
# H 1 2.036734693877551
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9731171365014593
# CQED-RHF One-electron energy      = -11.9731171365014593
# Nuclear repulsion energy          = 0.7794493984818638
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9713453412658133   dE = -7.97135E+00   dRMS = 1.56064E-12
# SCF Iteration   2: Energy = -7.9713453412658257   dE = -1.24345E-14   dRMS = 6.45376E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97134534 hartree
# Psi4  SCF energy: -7.97134534 hartree
#  Completed QED-RHF in 0.1270599365234375 seconds
#  Completed 1HSO Build in 0.0005879402160644531 seconds
#  Completed ERI Build in 0.027034282684326172 seconds
#  Completed 2D build in 0.023729801177978516 seconds
#  Completed 1G build in 7.104873657226562e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008749961853027344 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0018010139465332031 seconds
#  Completed constant offset matrix in 0.00017786026000976562 seconds
#  Completed Hamiltonian build in 0.3553431034088135 seconds
#
# Li
# H 1 2.053061224489796
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9578391618454933
# CQED-RHF One-electron energy      = -11.9578391618454933
# Nuclear repulsion energy          = 0.7732509937225647
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9704632244020424   dE = -7.97046E+00   dRMS = 1.61278E-12
# SCF Iteration   2: Energy = -7.9704632244020477   dE = -5.32907E-15   dRMS = 6.67045E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.97046322 hartree
# Psi4  SCF energy: -7.97046322 hartree
#  Completed QED-RHF in 0.12419295310974121 seconds
#  Completed 1HSO Build in 0.0006060600280761719 seconds
#  Completed ERI Build in 0.027429819107055664 seconds
#  Completed 2D build in 0.023192167282104492 seconds
#  Completed 1G build in 7.796287536621094e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008730888366699219 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001728057861328125 seconds
#  Completed constant offset matrix in 0.0001678466796875 seconds
#  Completed Hamiltonian build in 0.35206079483032227 seconds
#
# Li
# H 1 2.069387755102041
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9427376675550381
# CQED-RHF One-electron energy      = -11.9427376675550381
# Nuclear repulsion energy          = 0.7671503941665679
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9695692041497379   dE = -7.96957E+00   dRMS = 1.66922E-12
# SCF Iteration   2: Energy = -7.9695692041497468   dE = -8.88178E-15   dRMS = 6.90515E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96956920 hartree
# Psi4  SCF energy: -7.96956920 hartree
#  Completed QED-RHF in 0.12361288070678711 seconds
#  Completed 1HSO Build in 0.0007021427154541016 seconds
#  Completed ERI Build in 0.027566909790039062 seconds
#  Completed 2D build in 0.024000883102416992 seconds
#  Completed 1G build in 7.200241088867188e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008661746978759766 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017368793487548828 seconds
#  Completed constant offset matrix in 0.00016689300537109375 seconds
#  Completed Hamiltonian build in 0.35273122787475586 seconds
#
# Li
# H 1 2.085714285714286
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9278101568466788
# CQED-RHF One-electron energy      = -11.9278101568466788
# Nuclear repulsion energy          = 0.7611453030184931
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9686641658544470   dE = -7.96866E+00   dRMS = 1.73003E-12
# SCF Iteration   2: Energy = -7.9686641658544293   dE =  1.77636E-14   dRMS = 7.15837E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96866417 hartree
# Psi4  SCF energy: -7.96866417 hartree
#  Completed QED-RHF in 0.12574386596679688 seconds
#  Completed 1HSO Build in 0.0005872249603271484 seconds
#  Completed ERI Build in 0.026950836181640625 seconds
#  Completed 2D build in 0.024048805236816406 seconds
#  Completed 1G build in 6.723403930664062e-05 seconds
#  Completed the Dipole Matrix Build in 0.000865936279296875 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017349720001220703 seconds
#  Completed constant offset matrix in 0.0001900196075439453 seconds
#  Completed Hamiltonian build in 0.35375189781188965 seconds
#
# Li
# H 1 2.1020408163265305
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.9130541747459819
# CQED-RHF One-electron energy      = -11.9130541747459819
# Nuclear repulsion energy          = 0.7552334948397089
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9677489522230704   dE = -7.96775E+00   dRMS = 1.79495E-12
# SCF Iteration   2: Energy = -7.9677489522230598   dE =  1.06581E-14   dRMS = 7.42890E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96774895 hartree
# Psi4  SCF energy: -7.96774895 hartree
#  Completed QED-RHF in 0.1245272159576416 seconds
#  Completed 1HSO Build in 0.0008571147918701172 seconds
#  Completed ERI Build in 0.02652597427368164 seconds
#  Completed 2D build in 0.023802757263183594 seconds
#  Completed 1G build in 6.604194641113281e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008630752563476562 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017268657684326172 seconds
#  Completed constant offset matrix in 0.0001659393310546875 seconds
#  Completed Hamiltonian build in 0.3524589538574219 seconds
#
# Li
# H 1 2.1183673469387756
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8984673074615532
# CQED-RHF One-electron energy      = -11.8984673074615532
# Nuclear repulsion energy          = 0.7494128127985549
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9668243653900443   dE = -7.96682E+00   dRMS = 1.86332E-12
# SCF Iteration   2: Energy = -7.9668243653900301   dE =  1.42109E-14   dRMS = 7.71349E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96682437 hartree
# Psi4  SCF energy: -7.96682437 hartree
#  Completed QED-RHF in 0.12443780899047852 seconds
#  Completed 1HSO Build in 0.000782012939453125 seconds
#  Completed ERI Build in 0.027395009994506836 seconds
#  Completed 2D build in 0.02490997314453125 seconds
#  Completed 1G build in 6.29425048828125e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008759498596191406 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001729726791381836 seconds
#  Completed constant offset matrix in 0.0001761913299560547 seconds
#  Completed Hamiltonian build in 0.3532888889312744 seconds
#
# Li
# H 1 2.1346938775510207
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8840471817534095
# CQED-RHF One-electron energy      = -11.8840471817534095
# Nuclear repulsion energy          = 0.7436811660467495
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9658911688718588   dE = -7.96589E+00   dRMS = 1.93523E-12
# SCF Iteration   2: Energy = -7.9658911688718446   dE =  1.42109E-14   dRMS = 8.01350E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96589117 hartree
# Psi4  SCF energy: -7.96589117 hartree
#  Completed QED-RHF in 0.1237020492553711 seconds
#  Completed 1HSO Build in 0.0007009506225585938 seconds
#  Completed ERI Build in 0.028298139572143555 seconds
#  Completed 2D build in 0.024029970169067383 seconds
#  Completed 1G build in 6.890296936035156e-05 seconds
#  Completed the Dipole Matrix Build in 0.0009012222290039062 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017502307891845703 seconds
#  Completed constant offset matrix in 0.0001919269561767578 seconds
#  Completed Hamiltonian build in 0.35276317596435547 seconds
#
# Li
# H 1 2.1510204081632653
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8697914642944582
# CQED-RHF One-electron energy      = -11.8697914642944582
# Nuclear repulsion energy          = 0.7380365272152751
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9649500894169130   dE = -7.96495E+00   dRMS = 2.00995E-12
# SCF Iteration   2: Energy = -7.9649500894169130   dE =  0.00000E+00   dRMS = 8.32443E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96495009 hartree
# Psi4  SCF energy: -7.96495009 hartree
#  Completed QED-RHF in 0.12483000755310059 seconds
#  Completed 1HSO Build in 0.0008828639984130859 seconds
#  Completed ERI Build in 0.02683115005493164 seconds
#  Completed 2D build in 0.023544788360595703 seconds
#  Completed 1G build in 7.605552673339844e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008728504180908203 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001741170883178711 seconds
#  Completed constant offset matrix in 0.0001678466796875 seconds
#  Completed Hamiltonian build in 0.35445308685302734 seconds
#
# Li
# H 1 2.1673469387755104
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8556978610235859
# CQED-RHF One-electron energy      = -11.8556978610235859
# Nuclear repulsion energy          = 0.7324769300234460
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9640018187558335   dE = -7.96400E+00   dRMS = 2.08715E-12
# SCF Iteration   2: Energy = -7.9640018187558317   dE =  1.77636E-15   dRMS = 8.64589E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96400182 hartree
# Psi4  SCF energy: -7.96400182 hartree
#  Completed QED-RHF in 0.12341189384460449 seconds
#  Completed 1HSO Build in 0.0007429122924804688 seconds
#  Completed ERI Build in 0.027842998504638672 seconds
#  Completed 2D build in 0.023308753967285156 seconds
#  Completed 1G build in 8.0108642578125e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008809566497802734 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.001730203628540039 seconds
#  Completed constant offset matrix in 0.00015878677368164062 seconds
#  Completed Hamiltonian build in 0.3529942035675049 seconds
#
# Li
# H 1 2.183673469387755
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8417641164898626
# CQED-RHF One-electron energy      = -11.8417641164898626
# Nuclear repulsion energy          = 0.7270004669952337
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9630470152586401   dE = -7.96305E+00   dRMS = 2.16656E-12
# SCF Iteration   2: Energy = -7.9630470152586579   dE = -1.77636E-14   dRMS = 8.97695E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96304702 hartree
# Psi4  SCF energy: -7.96304702 hartree
#  Completed QED-RHF in 0.12468194961547852 seconds
#  Completed 1HSO Build in 0.0007290840148925781 seconds
#  Completed ERI Build in 0.026544809341430664 seconds
#  Completed 2D build in 0.02303004264831543 seconds
#  Completed 1G build in 6.914138793945312e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008640289306640625 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017330646514892578 seconds
#  Completed constant offset matrix in 0.00015997886657714844 seconds
#  Completed Hamiltonian build in 0.3536109924316406 seconds
#
# Li
# H 1 2.2
# symmetry c1
#
#
# Start SCF iterations:
#
# Canonical RHF One-electron energy = -11.8279880131879054
# CQED-RHF One-electron energy      = -11.8279880131879054
# Nuclear repulsion energy          = 0.7216052872772727
# Dipole energy                     = 0.0000000000000000
# SCF Iteration   1: Energy = -7.9620863055039024   dE = -7.96209E+00   dRMS = 2.24769E-12
# SCF Iteration   2: Energy = -7.9620863055039113   dE = -8.88178E-15   dRMS = 9.31498E-13
# Total time for SCF iterations: 0.003 seconds
#
# QED-RHF   energy: -7.96208631 hartree
# Psi4  SCF energy: -7.96208631 hartree
#  Completed QED-RHF in 0.1252741813659668 seconds
#  Completed 1HSO Build in 0.0007801055908203125 seconds
#  Completed ERI Build in 0.026658058166503906 seconds
#  Completed 2D build in 0.024316787719726562 seconds
#  Completed 1G build in 6.413459777832031e-05 seconds
#  Completed the Dipole Matrix Build in 0.0008671283721923828 seconds
# Generating all determinants in active space
#  Completed determinant list in 0.0017189979553222656 seconds
#  Completed constant offset matrix in 0.00019407272338867188 seconds
#  Completed Hamiltonian build in 0.35260581970214844 seconds

# %%
from matplotlib import pyplot as plt

# %%
print(r_array)
print(E_array[:,1]-E_array[:,0])

plt.plot(r_array, E_array[:,0]+0.1208, label="E0")
plt.plot(r_array, E_array[:,1], label="E1")
plt.plot(r_array, E_array[:,2], label="E2")
plt.plot(r_array, E_array[:,3], label="E3")
plt.legend()
#plt.xlim(1.79, 1.81)
plt.show()
# Out:
# [1.4        1.41632653 1.43265306 1.44897959 1.46530612 1.48163265
#  1.49795918 1.51428571 1.53061224 1.54693878 1.56326531 1.57959184
#  1.59591837 1.6122449  1.62857143 1.64489796 1.66122449 1.67755102
#  1.69387755 1.71020408 1.72653061 1.74285714 1.75918367 1.7755102
#  1.79183673 1.80816327 1.8244898  1.84081633 1.85714286 1.87346939
#  1.88979592 1.90612245 1.92244898 1.93877551 1.95510204 1.97142857
#  1.9877551  2.00408163 2.02040816 2.03673469 2.05306122 2.06938776
#  2.08571429 2.10204082 2.11836735 2.13469388 2.15102041 2.16734694
#  2.18367347 2.2       ]
# [0.14645286 0.14553992 0.14460568 0.14365108 0.14267704 0.14168441
#  0.14067401 0.1396466  0.13860294 0.13754372 0.13646963 0.13538131
#  0.13427939 0.13316448 0.13203718 0.13089806 0.1297477  0.12858665
#  0.12741549 0.12623476 0.12504505 0.12384694 0.12264101 0.12142788
#  0.12020819 0.1189826  0.11775179 0.1165165  0.11527748 0.11403551
#  0.11279144 0.1115461  0.11030038 0.10905519 0.10781145 0.10657009
#  0.10533203 0.10409816 0.10286937 0.10164649 0.10043027 0.09922144
#  0.09802059 0.09682825 0.09564484 0.09447068 0.09330596 0.09215079
#  0.09100515 0.08986894]

# %% [markdown]
# \begin{equation}
# \hat{H}_{\alpha n, \beta m} = \left( E_{\alpha}(R) + n \omega \right) \delta_{\alpha \beta} \delta_{nm} + \sqrt{\frac{\omega}{2}} \lambda \cdot \mu_{\alpha \beta}(R) \left(\sqrt{n} \delta_{n,m-1} + \sqrt{n+1} \delta_{n,m+1} \right)  \\
# +\frac{1}{2} \sum_{\gamma = 1}^N \lambda \cdot \mu_{\alpha, \gamma}(R) \lambda \cdot \mu_{\gamma, \beta} \delta_{nm}
# \end{equation}

# %%
def build_pf_hamiltonian(n_el, n_ph, E_R, omega, lamvec, mu):
    """
    Given an array of n_el E_R values and an n_ph states with fundamental energy omega
    build the PF Hamiltonian
    
    n_el : int
        the number of electronic states (n_el = 1 means only ground-state)
    
    n_ph : int
        the number of photon occupation states (n_ph = 1 means only the |0> state)
    
    E_R : np.array of floats
        the electronic energies
        
    omega : float
        the energy of the photonic mode
        
    lamvec : np.array of floats
        the lambda vector
        
    mu : (n_el x n_el x 3) np.array of floats 
        mu[i, j, k] is the kth cartesian component of the dipole moment expectation value between 
        state i and state j
    
    """
    H_PF = np.zeros((n_el * n_ph, n_el * n_ph))
    
    # take care of the diagonals first
    # bare electronic and photonic energy
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            H_PF[na,na] = E_R[a] + n * omega
        
    # diagonal dipole self energy
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            for g in range(n_el):
                H_PF[na,na] += 0.5 * np.dot(lamvec, mu[a,g,:]) * np.dot(lamvec, mu[g,a,:])
            
    # off-diagonal dipole self energy
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            for b in range(n_el):
                nb = n * n_el + b
                for g in range(n_el):
                    if a != b:
                        H_PF[na, nb] += 0.5 * np.dot(lamvec, mu[a,g,:]) * np.dot(lamvec, mu[g, b, :])
                
    # off-diagonal bilinear coupling
    for n in range(n_ph):
        for a in range(n_el):
            na = n * n_el + a
            
            for m in range(n_ph):
                for b in range(n_el):
                    mb = m * n_el + b
                    
                    if n == (m-1) and a != b:
                        #print(n, a, na, m, b, mb)
                        H_PF[na,mb] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m) 
                        H_PF[mb, na] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m) 
                        
                    elif n == (m+1) and a != b:
                        #print(n, a, na, m, b, mb)
                        H_PF[na, mb] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m+1) 
                        H_PF[mb, na] = -np.sqrt(omega / 2) * np.dot(lamvec, mu[a,b,:]) * np.sqrt(m+1)
                        
    
    return H_PF

# %% [markdown]
# \begin{equation}
# \hat{H}_{\alpha n, \beta m} = \left( E_{\alpha}(R) + n \omega \right) \delta_{\alpha \beta} \delta_{nm} + \sqrt{\frac{\omega}{2}} \lambda \cdot \mu_{\alpha \beta}(R) \left(\sqrt{n} \delta_{n,m-1} + \sqrt{n+1} \delta_{n,m+1} \right)  \\
# +\frac{1}{2} \sum_{\gamma = 1}^N \lambda \cdot \mu_{\alpha, \gamma}(R) \lambda \cdot \mu_{\gamma, \beta} \delta_{nm}
# \end{equation}

# %%
np.set_printoptions(precision=6, linewidth=200, suppress=True)
omega_cav = 0.12086
lambda_vector = np.array([0., 0., 0.08])
N_el = 3
N_ph = 2

_HPF = build_pf_hamiltonian(N_el, N_ph, E_array[0,:], omega_cav, lambda_vector, Mu_array[0, :, :, :])
print("H")
print(_HPF)
# Out:
# H
# [[-7.963336  0.        0.001246  0.       -0.       -0.011658]
#  [ 0.       -7.813517  0.       -0.        0.       -0.      ]
#  [ 0.001246  0.       -7.797646 -0.011658 -0.        0.      ]
#  [ 0.       -0.       -0.011658 -7.842476  0.        0.001246]
#  [-0.        0.       -0.        0.       -7.692657  0.      ]
#  [-0.011658 -0.        0.        0.001246  0.       -7.676786]]

# %% [markdown]
# We want to investigate the mean absolute error of a given polariton potential energy surface as a
# function of electronic and photonic truncation:
#
# $$ {\rm MAE} = \frac{1}{N_R} \sum_i^{N_R} \left| E(R_i) - E^{'}(R_i) \right| $$
#
# where $E^{'}(R_i)$ is a value of the polaritonic PES for a truncated level of theory and $E(R_i)$ is the exact value.

# %%
def MAE(E, Ep):
    """
    function to return the mean absolute error of the approximate PES stored in Ep relative to 
    the exact PES stored in E
    """
    # get length
    _NR = len(E)
    
    # take element-by-element difference
    _diff = E - Ep
    
    # compute absolute value of differences
    _absdiff = np.abs(_diff)
    
    # return sum divided by _NR
    return np.sum(_absdiff) / _NR

# %%
N_el = 50
N_ph = 2

#PF_EIG = np.zeros((N_R, N_el * N_ph))
#PF_5050 = np.zeros((N_R, N_el * N_ph))
MAE_array = np.zeros((20,20,3))
N_el_array = np.linspace(2, 21, 20, dtype=int)
N_ph_array = np.linspace(2, 21, 20, dtype=int)
print(N_el_array)
print(N_ph_array)

# %%
N_el = 10
N_ph = 10
pf_array = np.zeros((N_R, N_el * N_ph ))
for k in range(N_R):           
    _HPF = build_pf_hamiltonian(N_el, N_ph, E_array[k,:], omega_cav, lambda_vector, Mu_array[k, :, :, :])
    pf_e, pf_c = np.linalg.eigh(_HPF)
    pf_array[k,:] = pf_e



#print(r_array[i], pf_e[0], pf_e[1],  pf_e[2], pf_e[2])
#mae_g = MAE(pf_tmp[:,0], PF_5050[:,0])
#mae_lp = MAE(pf_tmp[:,1], PF_5050[:,1])
#mae_up = MAE(pf_tmp[:,2], PF_5050[:,2])
#MAE_array[i, j, 0] = mae_g
#MAE_array[i, j, 1] = mae_lp
#MAE_array[i, j, 2] = mae_up
#print(F'Nel : {N_el}, Nph : {N_ph}, mae_g : {mae_g}, mae_lp : {mae_lp}, mae_up : {mae_up}')

# %%
#plt.plot(r_array, Eg_QED_FCI_Np_1)
plt.plot(r_array, pf_array[:,0])
plt.plot(r_array, pf_array[:,1])
#plt.plot(r_array, E3_QED_FCI_Np_1, label="QED-FCI")
#plt.plot(r_array, E3_QED_FCI_Np_5, label="QED-FCI")
plt.plot(r_array, pf_array[:,2])
plt.plot(r_array, pf_array[:,3])
#plt.plot(r_array, pf_array[:,4])
plt.legend()

# %%
for i in range(N_R):
    print(F'{r_array[i]}, {pf_array[i,0]}, {pf_array[i,1]}, {pf_array[i,2]}, {pf_array[i,3]}, {pf_array[i,3]} ')
# Out:
# 1.4, -7.963574084574532, -7.846386905206224, -7.806893543510758, -7.790522708002686, -7.790522708002686
# 1.4163265306122448, -7.964527852773334, -7.847482557824718, -7.809010197477407, -7.79239571395422, -7.79239571395422
# 1.4326530612244897, -7.965355387354062, -7.848461045320013, -7.811029946824015, -7.794163153931648, -7.794163153931648
# 1.4489795918367345, -7.966063205944966, -7.849329487561599, -7.812958842655608, -7.795830286705596, -7.795830286705596
# 1.4653061224489796, -7.966657491345606, -7.85009472187073, -7.81480266412399, -7.797402047194414, -7.797402047194414
# 1.4816326530612245, -7.9671441103873395, -7.850763326835603, -7.8165669284454, -7.7988830544683365, -7.7988830544683365
# 1.4979591836734694, -7.967528631638945, -7.851341645321995, -7.818256900634965, -7.800277619139787, -7.800277619139787
# 1.9551020408163267, -7.952669544438841, -7.852450680148731, -7.849750218024028, -7.816832579256294, -7.816832579256294
# 1.9714285714285715, -7.951613305314838, -7.852571038411127, -7.850554736138324, -7.817045470707391, -7.817045470707391
# 1.9877551020408164, -7.950538888661948, -7.852717022931136, -7.851333749997206, -7.817236490171722, -7.817236490171722
# 2.0040816326530613, -7.949447474230382, -7.8528865758013175, -7.852085346939634, -7.81740648818927, -7.81740648818927
# 2.0204081632653064, -7.9483401941567395, -7.853077134444838, -7.852807679464239, -7.817556305820616, -7.817556305820616
# 2.036734693877551, -7.947218139904897, -7.853499041375046, -7.8532857309143225, -7.81768678240649, -7.81768678240649
# 2.053061224489796, -7.946082369513342, -7.854157941128286, -7.853509104006059, -7.81779876240224, -7.81779876240224
# 2.069387755102041, -7.944933914987624, -7.854783168405504, -7.8537438180261105, -7.817893101004978, -7.817893101004978
# 2.085714285714286, -7.943773789640269, -7.855373850166714, -7.853986381762899, -7.8179706683306645, -7.8179706683306645
# 2.1020408163265305, -7.942602995162079, -7.855929493032262, -7.854233361476158, -7.8180323519660355, -7.8180323519660355
# 2.1183673469387756, -7.941422528207664, -7.8564500097470935, -7.854481482445025, -7.81807905780152, -7.81807905780152
# 2.1346938775510207, -7.940233386302864, -7.856935728611109, -7.854727714742002, -7.818111709150363, -7.818111709150363
# 2.1510204081632653, -7.939036572923112, -7.857387385977372, -7.854969340275639, -7.818131244256689, -7.818131244256689
# 2.1673469387755104, -7.9378331016510275, -7.85780610309191, -7.8552039996317635, -7.818138612387736, -7.818138612387736
# 2.183673469387755, -7.936623999388566, -7.85819334954409, -7.855429718689578, -7.818134768782041, -7.818134768782041
# 2.2, -7.9354103086658485, -7.858550896316427, -7.8556449162621425, -7.818120668777355, -7.818120668777355

# %%
# we will compare to this!
#PF_2020 = np.copy(PF_EIG)
#PF_22 = np.copy(PF_EIG)

print(MAE(PF_5020[:,0], PF_2020[:,0]))
print(MAE(PF_5020[:,1], PF_2020[:,1]))
print(MAE(PF_5020[:,2], PF_2020[:,2]))

print(MAE(PF_5050[:,0], PF_2020[:,0]))
print(MAE(PF_5050[:,1], PF_2020[:,1]))
print(MAE(PF_5050[:,2], PF_2020[:,2]))

print(MAE(PF_5050[:,0], PF_5020[:,0]))
print(MAE(PF_5050[:,1], PF_5020[:,1]))
print(MAE(PF_5050[:,2], PF_5020[:,2]))
#omega_cav = 0.120000
#lambda_vector = np.array([0, 0.0, 0.05])
#numpy.savetxt(fname, X, fmt='%.18e', delimiter=' ', newline='\n', header='', footer='', comments='# ', encoding=None)[source]
np.savetxt('PF_5050_om_zp12_lamz_zp05.out', PF_5050, fmt='%16.12e', delimiter=',', newline='\n', header="N_el = 50, N_ph = 50, omega = 0.12, lambda = 0., 0., 0.05, r_array = np.linspace(1.4, 2.2, N_R)" )

# %%
for i in range(20):

    for j in range(20):
        N_el = N_el_array[i]
        N_ph = N_ph_array[j]
        print(F'{N_el}, {N_ph}, {MAE_array[i, j, 0]}, {MAE_array[i, j, 1]}, {MAE_array[i, j, 2]}')
        
    print('')

# %%
#plt.plot(r_array, PF_2020[:,0], 'black', label="LP - 20-20")
#plt.plot(r_array, PF_WTRIP[:,0], 'ro', label="LP - 2-2")
plt.plot(r_array, PF_2020[:,1], 'r--', label="LP - 20-2")
plt.plot(r_array, PF_WTRIP[:,2], 'purple', label="UP - 20-20")
plt.plot(r_array, PF_2020[:,2], 'b--', label="UP - 20-2")
plt.plot(r_array, PF_WTRIP[:,3], 'bo', label="UP - 2-2")
plt.legend()
plt.show()


plt.plot(r_array,PF_2020[:,2]- PF_WTRIP[:,3])
#plt.xlim(1.62, 2.2)
plt.show()

print(PF_2020[:,2]- PF_WTRIP[:,3])

# %%
plt.plot(r_array, PF_2020[:,1], 'black', label="LP - 20-20")
plt.plot(r_array, PF_22[:,1], 'ro', label="LP - 2-2")
plt.plot(r_array, PF_202[:,1], 'r--', label="LP - 20-2")
plt.plot(r_array, PF_2020[:,2], 'purple', label="UP - 20-20")
plt.plot(r_array, PF_202[:,2], 'b--', label="UP - 20-2")
plt.plot(r_array, PF_22[:,2], 'bo', label="UP - 2-2")
plt.legend()
plt.show()

#plt.plot(r_array, PF_EIG[:,2], 'b--')
#plt.plot(r_array, E_array[:,0]+omega_cav)
#plt.plot(r_array, E_array[:,2])
#plt.plot(r_array, E_array[:,3])
#plt.plot(r_array, PF_EIG[:,3])
#plt.plot(r_array, PF_EIG[:,4])
#plt.plot(r_array, PF_EIG[:,5])

# %%
mol_str = """
Li
H 1 1.8
symmetry c1
"""

options_dict = {
    "basis": "sto-3g",
    "scf_type": "pk",
    "e_convergence": 1e-10,
    "d_convergence": 1e-10,
    "save_jk" : True
}

cavity_dict = {
    'omega_value' : 0.0,
    'lambda_vector' : np.array([0, 0, 0]),
    'ci_level' : 'fci',
    'full_diagonalization' : True,
    'number_of_photons' : 0
}



E_r_1p8_array = np.zeros(N_el)
Mu_r_1p8_array = np.zeros((N_el, N_el, 3))



mol = psi4.geometry(mol_str)
scf_e, wfn = psi4.energy('SCF', return_wfn=True)
fci_energy = psi4.energy('fci',ref_wfn=wfn)

LiH = PFHamiltonianGenerator(mol_str, options_dict, cavity_dict)
assert np.isclose(fci_energy, LiH.CIeigs[0], 1e-7)
# sort out states with dipole-allowed transition from ground state
singlet_states = LiH.sort_dipole_allowed_states( N_el)
E_r_1p8_array[:] = LiH.CIeigs[singlet_states]
Mu_r_1p8_array = LiH.compute_dipole_moments(singlet_states)

# %%
lam_z = np.linspace(0, 0.1, 50)
pol_v_l = np.zeros((50,3))
print(lam_z)

# %%
N_el = 20
N_ph = 20
for i in range(50):
    lambda_vector[2] = lam_z[i]           
    _HPF = build_pf_hamiltonian(N_el, N_ph, E_array[k,:], omega_cav, lambda_vector, Mu_array[k, :, :, :])
    pf_e, pf_c = np.linalg.eigh(_HPF)
    pol_v_l[i,:] = pf_e[:3]
    print(lam_z[i], pf_e[0], pf_e[1], pf_e[2])

# %%
plt.plot(lam_z, pol_v_l[:,0], label='g')
plt.plot(lam_z, pol_v_l[:,1], label='LP')
plt.plot(lam_z, pol_v_l[:,2], label='UP')

plt.legend()
plt.show()
