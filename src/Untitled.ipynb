# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
r = np.linspace(2.2, 2.8, 6)
print(r)


with open('mghp_data.json', 'r') as file:
    data = json.load(file)

energies = np.array(data["return_results"]["casci_energies"])
# Out:
# [2.2  2.32 2.44 2.56 2.68 2.8 ]

# %%
plt.plot(r, energies[:,0], 'r-o')
